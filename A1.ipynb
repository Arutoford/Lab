# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv ('Desktop/0.csv')

# %%
# Out:
#    26.0  4.0  5.0   8.0  -1.0  -13.0  -109.0  -66.0  -9.0  2.0  ...  -28.0  \
# 0 -47.0 -6.0 -5.0  -7.0  13.0   -1.0    35.0  -10.0  10.0 -4.0  ...  -25.0
# 1 -19.0 -8.0 -8.0  -8.0 -21.0   -6.0   -79.0   12.0   0.0  5.0  ...  -83.0
# 2   2.0  3.0  0.0   2.0   0.0   22.0   106.0  -14.0 -16.0 -2.0  ...  -38.0
# 3   6.0  0.0  0.0  -2.0 -14.0   10.0   -51.0    5.0   7.0  0.0  ...   38.0
# 4  15.0 -5.0 -5.0 -15.0  12.0  -22.0   -38.0   36.0   9.0  6.0  ...  -26.0
#
#    61.0  4.0.3  8.0.1  5.0.1  4.0.4  -7.0.1  -59.0  16.0  0
# 0  47.0    6.0    6.0    5.0   13.0    21.0  111.0  15.0  0
# 1   7.0    7.0    1.0   -8.0    7.0    21.0  114.0  48.0  0
# 2 -11.0    4.0    7.0   11.0   33.0    39.0  119.0  43.0  0
# 3 -35.0   -8.0    2.0    6.0  -13.0   -24.0 -112.0 -69.0  0
# 4   5.0    6.0    6.0   11.0    5.0    30.0  -48.0  25.0  0
#
# [5 rows x 65 columns]

# %%
data['26.0'].value_counts()
# Out:
#  0.0      89
#  1.0      78
# -1.0      78
# -3.0      77
# -2.0      77
#           ..
# -85.0      1
#  73.0      1
# -58.0      1
#  110.0     1
# -69.0      1
# Name: 26.0, Length: 176, dtype: int64

# %%
data['26.0'].hist();

# %%
data['5.0'].hist();

# %%
data['-13.0'].value_counts()
# Out:
# -1.0     122
# -3.0     114
#  1.0     107
#  0.0     105
#  2.0      97
#         ...
# -69.0      1
#  68.0      1
# -45.0      1
#  61.0      1
#  66.0      1
# Name: -13.0, Length: 151, dtype: int64

# %%
plt.scatter(data['-13.0'],data['2.0']);
plt.xlabel('-13.0')
plt.ylabel('2.0')
# Out:
# Text(0, 0.5, '2.0')

# %%
plt.scatter(data['-9.0'],data['16.0']);
plt.xlabel('-9.0')
plt.ylabel('16.0')
# Out:
# Text(0, 0.5, '16.0')

# %%
data1 = data[['-9.0','16.0']]
data1.plot();

# %%
data2 = data[['-9.0','16.0']]
for column in data2.columns:
    data2[column] = (data2[column] - data2[column].min()) / (data2[column].max() - data2[column].min())    
data2.plot();
# Out:
# C:\Users\aruto\AppData\Local\Temp\ipykernel_5564\640031170.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2[column] = (data2[column] - data2[column].min()) / (data2[column].max() - data2[column].min())

# %%
data.corr()
# Out:
#             26.0       4.0       5.0       8.0      -1.0     -13.0    -109.0  \
# 26.0    1.000000  0.162744  0.021050 -0.023476  0.065439  0.125551  0.183974
# 4.0     0.162744  1.000000  0.372532  0.048195  0.016564  0.127895  0.116512
# 5.0     0.021050  0.372532  1.000000  0.466701  0.111431  0.162809  0.092754
# 8.0    -0.023476  0.048195  0.466701  1.000000  0.076548  0.005399  0.001240
# -1.0    0.065439  0.016564  0.111431  0.076548  1.000000  0.381232  0.179261
# ...          ...       ...       ...       ...       ...       ...       ...
# 4.0.4  -0.050571 -0.041933 -0.000053  0.002120  0.009778 -0.046077 -0.023552
# -7.0.1 -0.011544 -0.025675 -0.051235 -0.052179 -0.012043 -0.057643  0.012573
# -59.0  -0.025189 -0.035281 -0.018654 -0.004456 -0.021569 -0.075897 -0.024211
# 16.0   -0.001905 -0.025793 -0.020235 -0.013414 -0.036765 -0.086639 -0.025833
# 0            NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
sns.heatmap(data.corr());
